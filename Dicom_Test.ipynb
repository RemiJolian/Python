# %% [markdown]
# <a href="https://colab.research.google.com/github/RemiJolian/Python/blob/master/Dicom_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive
# Out:
# /content/drive

# %%
# !ls
# Out:
# MyDrive

# %%
# %cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !ls
# Out:
#  027_20210720.rar
#  047-011599.zip
# '1795 1393.03.26 001.jpg'
#  20220926_134834.jpg
# '5 question.pdf'
# 'ADP Files'
#  Arlington.rar
# 'Background Assignment_ZKU.pdf'
# 'Background Assignment_ZKU_Rev.docx'
# 'Background Assignment_ZKU_Rev_Final.pdf'
# 'Background HW.docx'
# 'Ballot Contract_modify.txt'
# 'Ballot contract-Ramin'
#  Brochure.gdoc
# 'Cohort 4'
# 'Colab Notebooks'
# 'Computer & Programming'
#  DSC01721.JPG
#  DSC_0391.JPG
#  DSC_0396.JPG
# 'Farzad Kamangar.pdf'
# 'Final_Ramin_Background Assignment_ZKU.pdf'
#  FXRD-1417W_FW_V01.26.vhdr
#  GenwareMP.rar
# 'ImageFile_3006371f-1c4f-4969-8860-0350063b7a9d_000046004 - Copy.png'
#  IMG-5240.jpg
#  OPG
# 'Ostad Shajarian.jpg'
# '[PCH-2500_TEC]Chapter2_Spare_Part_List_1.0_Eng.pdf'
#  PROJ_20221010112907.rar
#  PsiphonAndroid.apk
#  Python
#  Rahzani_Abas_13112018_201045.jpg
#  Sajedi_Abbas_11042019_181649.jpg
#  Solidity_Code
# 'Stanford Online Course'
# 'Untitled document.docx'
# 'Untitled document.gdoc'
# ...

# %%
# %cd Python
# Out:
# /content/drive/MyDrive/Python

# %%
# !ls
# Out:
# 'Dicom File'

# %%
# !pip install pydicom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 21.5 MB/s eta 0:00:00
# ...

# %%
import pydicom

# %%
import matplotlib.pyplot as plt

# %%
from pathlib import Path

# %%
pyfile_dcm = pydicom.read_file('Dicom File/PX20201028_183241_0000_00000357.dcm')

# %%
pyfile_dcm
# Out:
# /usr/local/lib/python3.8/dist-packages/pydicom/valuerep.py:290: UserWarning: The value length (18) exceeds the maximum length of 16 allowed for VR SH.
#   warnings.warn(msg)
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 196
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Computed Radiography Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.410.200028.1070000718.20201028183241.1.1
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.840.113654.20180829110420.1003
# (0002, 0013) Implementation Version Name         SH: 'VATECH_DICOM_V1003'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: ''
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# ...

# %%
pyfile_dcm[0x008,0x0022]
# Out:
# (0008, 0022) Acquisition Date                    DA: '20201028'

# %%
pyfile_dcm.ExposureTime
# Out:
# '13500'

# %%
opg1 = pyfile_dcm.pixel_array
plt.figure()
plt.imshow(opg1,cmap='gray')
